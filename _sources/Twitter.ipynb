# %% [markdown]
# # Scraping Pada Twitter

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
query = "(ridwankamil) until:2023-02-20 since:2022-01-01"
tweets = []
limit = 500

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
  if len(tweets)==limit:
    break
  else:
    tweets.append([tweet.date, tweet.user.username, tweet.content, tweet.user.location])
# Out:
# <ipython-input-3-63ecd82edac9>:9: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.user.username, tweet.content, tweet.user.location])

# %%
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet', 'lokasi'])
print(df)
df.to_csv('twitter.csv')
# Out:
#                          Date             User  \
# 0   2023-02-19 23:53:48+00:00       fikri_arif
# 1   2023-02-19 23:50:10+00:00  Adityasaputrooo
# 2   2023-02-19 23:48:46+00:00  Adityasaputrooo
# 3   2023-02-19 23:46:46+00:00  Adityasaputrooo
# 4   2023-02-19 23:43:07+00:00  Adityasaputrooo
# ..                        ...              ...
# 495 2023-02-18 02:34:15+00:00        AstiVijay
# 496 2023-02-18 02:26:41+00:00  AryoPen53916787
# 497 2023-02-18 02:26:11+00:00   amrullah_hyuga
# 498 2023-02-18 02:26:01+00:00           wakcis
# 499 2023-02-18 02:23:20+00:00       yurifirman
#
#                                                  Tweet  \
# 0    @RokiDermawan @toptobs @OfficialVBogor Saya be...
# 1    SPIN mengajukan pertanyaan jika pemilihan pres...
# 2    Gubernur Jabar @ridwankamil mengatakan saat in...
# 3    "Ini adalah arahan Pak Jokowi untuk memulai pe...
# 4    "Gini, saya kepada semua orang yang ingin maju...
# ..                                                 ...
# 495          @ridwankamil hayooolooooo dr 2015 nicchhh
# 496  @kurawa @ridwankamil  karena sudah jadi kader ...
# 497  Siapa tau kan tiba2 di benerin sama pak gubern...
# 498  spt biasa, semua hanya rencana. dusta dalam be...
# 499  @ridwankamil @YudhaPraw liat tuh lsg eksyen bi...
#
#                       lokasi
# 0                  Tangerang
# 1       Indramayu, Indonesia
# 2       Indramayu, Indonesia
# 3       Indramayu, Indonesia
# 4       Indramayu, Indonesia
# ..                       ...
# 495  Bekasi Barat, Indonesia
# 496
# 497      Bandung, Jawa Barat
# 498
# 499        pangkalan jetski
#
# [500 rows x 4 columns]
